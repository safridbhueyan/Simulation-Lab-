# %% [markdown]
# Simulation and Modeling Lab
# **Course Code:** CSE 413
# **Name:** MD safrid bhuiyan
# **ID:** 0432310005101080
# **Sec:** 7B2; **Batch:** 53
# **Semester:** Spring 2026
# **Assignment No.:** 04

# %% [markdown]
# # Necessary Libraries

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns
import random
import math

# %% [markdown]
# # Part 1 —  Setup & Personalization

# %%
student_id = "0432310005101096"

# Extract R (last two digits)
R = int(student_id[-2:])

# Define new range
range_max = R / 10

# Define new radius
radius = R / 10

# Count letters only (ignore spaces)
num_letters = 19 # Md. Robiul Hassan Rabin = 19

# Number of random points
n = 200 * num_letters

print("R =", R)
print("Range = [0,", range_max, "]")
print("New Circle Radius =", radius)
print("Number of Letters =", num_letters)
print("Total Random Points =", n)

# Generate random points
x = np.random.uniform(0, range_max, n)
y = np.random.uniform(0, range_max, n)
print(x)
print(y)
# Out:
# R = 96
# Range = [0, 9.6 ]
# New Circle Radius = 9.6
# Number of Letters = 19
# Total Random Points = 3800
# [5.28478734 5.09511647 5.17708229 ... 5.00652401 0.01760404 7.49728012]
# [4.13699931 6.26712987 6.21244486 ... 0.65555297 2.50318557 2.60812551]

# %% [markdown]
# #  Part 2 — Simulation Logic

# %%
# 1. Function to check inside circle
def is_inside_circle(x, y, r):
    return (x**2 + y**2) <= r**2

# 2. Two Random Methods
half = n // 2

inside_count = 0
outside_count = 0

# First Half: random.uniform()
for _ in range(half):
    x = random.uniform(0, range_max)
    y = random.uniform(0, range_max)

    if is_inside_circle(x, y, radius):
        inside_count += 1
    else:
        outside_count += 1

# Second Half: numpy.random.rand()
for _ in range(half):
    x = np.random.rand() * range_max   # scaled to [0, R/10]
    y = np.random.rand() * range_max

    if is_inside_circle(x, y, radius):
        inside_count += 1
    else:
        outside_count += 1

# 3. Final Running Counts
print("Total Points =", n)
print("Points Inside Circle =", inside_count)
print("Points Outside Circle =", outside_count)
# Out:
# Total Points = 3800
# Points Inside Circle = 2987
# Points Outside Circle = 813

# %% [markdown]
# # Part 3 — Output & Analysis

# %%
# Function to run simulation
def run_simulation(n):
    half = n // 2
    inside_count = 0

    # First half - random.uniform()
    for _ in range(half):
        x = random.uniform(0, range_max)
        y = random.uniform(0, range_max)
        if is_inside_circle(x, y, radius):
            inside_count += 1

    # Second half - np.random.rand()
    for _ in range(half):
        x = np.random.rand() * range_max
        y = np.random.rand() * range_max
        if is_inside_circle(x, y, radius):
            inside_count += 1

    # Adjusted π formula
    pi_est = (inside_count / n) * ((range_max**2) / (radius**2))

    error = abs(math.pi - pi_est)

    return inside_count, pi_est, error


# Print Table Header
print("Range Used | Total Points | Points Inside | Estimated Pi | Error from math.pi")
print("-"*75)

# Run 5 simulations
for i in range(1, 6):
    n = n * i
    inside, pi_value, error = run_simulation(n)

    print(f"[0,{range_max}] | {n} | {inside} | {pi_value:.6f} | {error:.6f}")
# Out:
# Range Used | Total Points | Points Inside | Estimated Pi | Error from math.pi
# ---------------------------------------------------------------------------
# [0,9.6] | 3800 | 2965 | 0.780263 | 2.361329
# [0,9.6] | 7600 | 5973 | 0.785921 | 2.355672
# [0,9.6] | 22800 | 17868 | 0.783684 | 2.357908
# [0,9.6] | 91200 | 71689 | 0.786064 | 2.355529
# [0,9.6] | 456000 | 358166 | 0.785452 | 2.356141
